# %% [markdown]
# ### What is Statistics?
#
# Statistics is the science of collecting, organizing, analyzing, interpreting, and presenting data.
# It helps convert raw data into meaningful insights for decision-making under uncertainty.

# %% [markdown]
# 1. Predicting sales and revenue trends
# 2. Customer segmentation and behavior analysis
# 3. Fraud detection in banking and finance
# 4. Medical data analysis and disease prediction
# 5. Quality control in manufacturing
# 6. Recommendation systems (Netflix, Amazon)

# %% [markdown]
# ### Structured vs Unstructured Data
#
# **Structured Data**
# - Organized in rows and columns
# - Easy to store in databases
# - Example: Excel sheets, SQL tables
#
# **Unstructured Data**
# - No fixed format
# - Harder to analyze
# - Example: Images, videos, emails, social media posts

# %% [markdown]
# ### Applications of Statistics
#
# - **Healthcare**: Disease prediction, patient monitoring
# - **Business**: Sales forecasting, profit analysis
# - **Marketing**: Customer targeting, A/B testing
# - **Finance**: Risk analysis, stock prediction
# - **Education**: Performance analysis

# %%
employee_sales = [
    {"Name": "Amit", "Sales": 50000, "Region": "North"},
    {"Name": "Neha", "Sales": 60000, "Region": "South"},
    {"Name": "Rahul", "Sales": 55000, "Region": "East"},
    {"Name": "Priya", "Sales": 70000, "Region": "West"}
]

employee_sales
# Out:
# [{'Name': 'Amit', 'Sales': 50000, 'Region': 'North'},
#  {'Name': 'Neha', 'Sales': 60000, 'Region': 'South'},
#  {'Name': 'Rahul', 'Sales': 55000, 'Region': 'East'},
#  {'Name': 'Priya', 'Sales': 70000, 'Region': 'West'}]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data = {
    "Name": ["Amit", "Neha", "Rahul", "Priya"],
    "Age": [25, 30, 28, 35],
    "Department": ["HR", "IT", "Sales", "IT"],
    "Salary": [40000, 60000, 50000, 70000]
}

df = pd.DataFrame(data)
df
# Out:
#     Name  Age Department  Salary
# 0   Amit   25         HR   40000
# 1   Neha   30         IT   60000
# 2  Rahul   28      Sales   50000
# 3  Priya   35         IT   70000

# %%
df.dtypes
# Out:
# Name          object
# Age            int64
# Department    object
# Salary         int64
# dtype: object

# %%
numerical_data = df.select_dtypes(include="number")
categorical_data = df.select_dtypes(include="object")

numerical_data, categorical_data
# Out:
# (   Age  Salary
#  0   25   40000
#  1   30   60000
#  2   28   50000
#  3   35   70000,
#      Name Department
#  0   Amit         HR
#  1   Neha         IT
#  2  Rahul      Sales
#  3  Priya         IT)

# %%
plt.hist(df["Age"], color='blue', alpha=0.7)
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

# %%
df["Department"].value_counts().plot(kind="bar", color='green', alpha=0.7)
plt.title("Department Count")
plt.xlabel("Department")
plt.ylabel("Count")
plt.show()

# %%
df["Department"].value_counts().plot(kind="pie", autopct="%1.1f%%", startangle=140, colors=sns.color_palette("pastel"), wedgeprops={'alpha':0.7})
plt.title("Department Percentage")
plt.ylabel("")
plt.show()

# %%
plt.boxplot(df["Salary"], vert=True, patch_artist=True, boxprops=dict(facecolor='orange', alpha=0.7))
plt.title("Salary Distribution")
plt.ylabel("Salary")
plt.show()

# %%
population = np.random.randint(40, 100, 1000)
sample = np.random.choice(population, 100)

# %%
population_mean = np.mean(population)
population_std = np.std(population)

sample_mean = np.mean(sample)
sample_std = np.std(sample)

population_mean, population_std, sample_mean, sample_std
# Out:
# (np.float64(69.606),
#  np.float64(17.692731954110425),
#  np.float64(67.47),
#  np.float64(17.161267435711153))

# %% [markdown]
# ### Population vs Sample Statistics
#
# - **Population statistics** describe the entire dataset.
# - **Sample statistics** estimate population values using a subset.
# - Sample values may slightly differ due to randomness.
# - Larger samples give more accurate population estimates.
